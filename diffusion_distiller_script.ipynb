# %%
# Use terminal
python ./sample.py --out_file ./images/celeba_u_6.png --module celeba_u --checkpoint ./checkpoints/celeba/base_6/checkpoint.pt --batch_size 1
# Out:
# Traceback (most recent call last):
#   File "./sample.py", line 3, in <module>
#     from v_diffusion import make_beta_schedule
#   File "E:\01-Research\03-Projects\20230801-暑研项目-Diffusion\02-代码\diffusion_distiller_autoweighted\v_diffusion.py", line 3, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %%
from IPython.display import Image
Image("./images/celeba/origin_pre/celeba_ori.png")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
# !python ./sample.py --out_file ./images/celeba_original_ts1.png --module celeba_u --time_scale 1 --checkpoint ./checkpoints/celeba/original/checkpoint.pt --batch_size 1
# Out:
# Traceback (most recent call last):
#   File "./sample.py", line 3, in <module>
#     from v_diffusion import make_beta_schedule
#   File "E:\01-Research\03-Projects\20230801-暑研项目-Diffusion\02-代码\diffusion_distiller_autoweighted\v_diffusion.py", line 3, in <module>
#     import torch
# ModuleNotFoundError: No module named 'torch'

# %%
Image("./images/celeba/original/celeba_original_ts1.png")

# %% [markdown]
# # Train the teacher diffusion model

# %%
# !python ./train.py --module celeba_u --name celeba --dname original

# %%
# !python ./sample.py --out_file ./images/celeba_original_ts1.png --module celeba_u --time_scale 1 --checkpoint ./checkpoints/celeba/original/checkpoint.pt --batch_size 1

# %%
from IPython.display import Image
Image("./images/celeba/original/celeba_original_ts1.png")

# %% [markdown]
# ### Evaluete the teacher model
